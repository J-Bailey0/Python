# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import numpy as np

# %%
#Loading data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
#Cleaning Data
df['job_posted_date']  = pd.to_datetime(df['job_posted_date'])
# Out:
# README.md:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
# The loc method specifies the row and column with string values able to be selected
# The iloc method requires index of both row and column to be selected
df.loc[0:10, 'salary_rate':'salary_hour_avg']
# Out:
#    salary_rate  salary_year_avg  salary_hour_avg
# 0         None              NaN              NaN
# 1         None              NaN              NaN
# 2         None              NaN              NaN
# 3         None              NaN              NaN
# 4         None              NaN              NaN
# 5         None              NaN              NaN
# 6         None              NaN              NaN
# 7         None              NaN              NaN
# 8         None              NaN              NaN
# 9         None              NaN              NaN
# 10        None              NaN              NaN

# %%
df.iloc[0:3, 0:3]
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location
# 0                 Watertown, CT
# 1  Guadalajara, Jalisco, Mexico
# 2               Berlin, Germany

# %%
df.loc[:, 'salary_rate':'salary_hour_avg'].dropna(subset='salary_rate')
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 28            year         109500.0              NaN
# 43            hour              NaN             97.5
# 51            hour              NaN             72.5
# 77            year         140000.0              NaN
# 92            year         120000.0              NaN
# ...            ...              ...              ...
# 785624        year         139216.0              NaN
# 785641        year         150000.0              NaN
# 785648        year         221875.0              NaN
# 785682        year         157500.0              NaN
# 785692        year         157500.0              NaN
#
# [33067 rows x 3 columns]

# %%
df.iloc[0:5]
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df.loc[:, 'salary_rate': 'salary_hour_avg']
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 0             None              NaN              NaN
# 1             None              NaN              NaN
# 2             None              NaN              NaN
# 3             None              NaN              NaN
# 4             None              NaN              NaN
# ...            ...              ...              ...
# 785736        None              NaN              NaN
# 785737        None              NaN              NaN
# 785738        None              NaN              NaN
# 785739        None              NaN              NaN
# 785740        None              NaN              NaN
#
# [785741 rows x 3 columns]

# %%
us_jobs = df[df['job_country']=='United States']

# %%
us_jobs.head(15)
# Out:
#          job_title_short                                          job_title  \
# 0   Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 3          Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5          Data Engineer                                  GCP Data Engineer
# 6   Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 9         Data Scientist                                  Data Scientist II
# 11         Data Engineer                                      Data Engineer
# 13  Senior Data Engineer                               Senior Data Engineer
# 17        Data Scientist                             Data Science Team Lead
# 26         Data Engineer                                      Data Engineer
# 27         Data Engineer  Principal Data Engineer (Lead), Knowledge Grap...
# 30  Senior Data Engineer     Senior Data Engineer (Work from home Eligible)
# ...

# %%
feb_jobs = df[df['job_posted_date'].dt.month == 2]

# %%
feb_jobs
# Out:
#              job_title_short  \
# 21            Data Scientist
# 27             Data Engineer
# 34              Data Analyst
# 35             Data Engineer
# 62            Data Scientist
# ...                      ...
# 784588         Data Engineer
# 784779  Senior Data Engineer
# 784994     Software Engineer
# 785142      Business Analyst
# 785402     Software Engineer
#
#                                                 job_title  \
# 21      Stage - data scientist – génération ia de donn...
# 27      Principal Data Engineer (Lead), Knowledge Grap...
# 34      Data Analyst als Marketing Manager Automation ...
# 35                            Data Engineer - Royal Canin
# 62                                         Data Scientist
# ...                                                   ...
# 784588                                      Data Engineer
# 784779                  Senior Data Engineer - SQL/Python
# 784994                    Microsoft Dynamics CRM Engineer
# ...

# %%
jan_jobs = df[df['job_posted_date'].dt.month == 1]

# %%
jan_jobs_Data_Analyst = df[df['job_title_short'] == 'Data Analyst']

# %%
jan_jobs_Data_Analyst_salary = jan_jobs_Data_Analyst.dropna(subset=['salary_year_avg'])
